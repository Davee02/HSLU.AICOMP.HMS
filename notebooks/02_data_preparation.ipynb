# %%
SKIP_NPY_CREATION = True # if True, the .npy files will not be created. Useful if you already have them and want to skip that step

# %%
import sys
import os

if bool(os.environ.get("KAGGLE_URL_BASE", "")):
  import sys
  # running on kaggle
  sys.path.insert(0, "/kaggle/input/hsm-source-files")
else:
  # running locally
  sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.datasets.eeg_processor import EEGDataProcessor
from src.utils.utils import get_raw_data_dir, get_processed_data_dir

DATA_PATH = get_raw_data_dir()
processor = EEGDataProcessor(raw_data_path=DATA_PATH, processed_data_path=get_processed_data_dir())
# Out:
# 2025-11-04 20:21:33,959 :: root :: INFO :: Initialising Utils
# 2025-11-04 20:21:35,369 :: root :: INFO :: Initialising Datasets
# Processor initialized.
# Raw data path: '/home/david/git/aicomp/data'
# Processed data path: '/home/david/git/aicomp/data/processed'

# %%
processed_df_max = processor.process_data(vote_method='max_vote_window', skip_parquet=False)
print("\nFinal Data Head (sum_and_normalize):")
display(processed_df_max.head())
# Out:
# ==================================================
# Starting EEG Data Processing Pipeline
# ==================================================
# Processing EEG files to Parquet:   0%|          | 0/17089 [00:00<?, ?it/s]
# Using 'max_vote_window' vote aggregation strategy.
#
# Processed train data saved to '/home/david/git/aicomp/data/processed/train_processed.csv'.
# Shape of the final dataframe: (17089, 12)
#
# Pipeline finished successfully!
# ==================================================
#
# Final Data Head (sum_and_normalize):
#    eeg_id  spectrogram_id  patient_id expert_consensus  seizure_vote  \
# 0  568657       789577333       20654            Other           0.0
# 1  582999      1552638400       20230              LPD           0.0
# 2  642382        14960202        5955            Other           0.0
# 3  751790       618728447       38549              GPD           0.0
# 4  778705        52296320       40955            Other           0.0
#
#    lpd_vote  gpd_vote  lrda_vote  grda_vote  other_vote  min_offset  \
# 0  0.000000      0.25   0.000000   0.166667    0.583333         0.0
# 1  0.857143      0.00   0.071429   0.000000    0.071429         0.0
# 2  0.000000      0.00   0.000000   0.000000    1.000000      1008.0
# 3  0.000000      1.00   0.000000   0.000000    0.000000       908.0
# 4  0.000000      0.00   0.000000   0.000000    1.000000         0.0
#
#    max_offset
# 0        16.0
# 1        38.0
# 2      1032.0
# 3       908.0
# 4         0.0

# %%
processed_df_max.to_csv('../data/processed_data_max_vote_window.csv', index=False)

# %%
processed_df_sum = processor.process_data(vote_method='sum_and_normalize', skip_parquet=True)

print("\nFinal Data Head (sum_and_normalize):")
display(processed_df_sum.head())
# Out:
# ==================================================
# Starting EEG Data Processing Pipeline
# ==================================================
# Skipping Parquet file creation as requested.
# Using 'sum_and_normalize' vote aggregation strategy with spectrogram info.
#
# Processed train data saved to '/home/david/git/aicomp/data/processed/train_processed.csv'.
# Shape of the final dataframe: (17089, 12)
#
# Pipeline finished successfully!
# ==================================================
#
# Final Data Head (sum_and_normalize):
#    eeg_id  spectrogram_id  min_offset  max_offset  patient_id  \
# 0  568657       789577333         0.0        16.0       20654
# 1  582999      1552638400         0.0        38.0       20230
# 2  642382        14960202      1008.0      1032.0        5955
# 3  751790       618728447       908.0       908.0       38549
# 4  778705        52296320         0.0         0.0       40955
#
#   expert_consensus  seizure_vote  lpd_vote  gpd_vote  lrda_vote  grda_vote  \
# 0            Other           0.0  0.000000      0.25   0.000000   0.166667
# 1              LPD           0.0  0.857143      0.00   0.071429   0.000000
# 2            Other           0.0  0.000000      0.00   0.000000   0.000000
# 3              GPD           0.0  0.000000      1.00   0.000000   0.000000
# 4            Other           0.0  0.000000      0.00   0.000000   0.000000
#
#    other_vote
# 0    0.583333
# 1    0.071429
# 2    1.000000
# 3    0.000000
# 4    1.000000

# %%
processed_df_sum.to_csv('../data/processed_data_sum_votes_window.csv', index=False)
